# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue"
headers = {"User-Agent": "MyProject/1.0 (binii@example.com)"}

page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
tables = pd.read_html(StringIO(str(soup)))
print(len(tables))  # see how many tables found
df = tables[0]
# Out:
# 6

# %%
df.to_csv("largest_company.csv", index=False)
print("saved!")
# Out:
# saved!

# %%
import os
os.getcwd()  # shows you where it saved
# Out:
# '/content'

# %%
from google.colab import files
files.download("largest_company.csv")

# %%
df=pd.read_csv("largest_company.csv")
df.head()
# Out:
#    Ranks                             Name                        Industry  \
# 0  Ranks                             Name                        Industry
# 1      1                           Amazon  Retail  Information technology
# 2      2                          Walmart                          Retail
# 3      3  State Grid Corporation of China                     Electricity
# 4      4                     Saudi Aramco                     Oil and gas
#
#              Revenue             Profit  Employees  Headquarters[note 1]  \
# 0  USD (in billions)  USD (in billions)  Employees  Headquarters[note 1]
# 1                716               79.9    1576000         United States
# 2                713               21.8    2100000         United States
# 3                545                9.2    1361423                 China
# 4                480              106.0      73311          Saudi Arabia
#
#    State-owned  Ref.
# 0  State-owned  Ref.
# 1          NaN   [5]
# ...

# %%
df = df.iloc[1:].reset_index(drop=True)  # clean
df.to_csv("largest_companies.csv", index=False)  # overwrite the old csv
print("saved!")
# Out:
# saved!

# %%
df.head()
# Out:
#   Ranks                                  Name                        Industry  \
# 0     1                                Amazon  Retail  Information technology
# 1     2                               Walmart                          Retail
# 2     3       State Grid Corporation of China                     Electricity
# 3     4                          Saudi Aramco                     Oil and gas
# 4     5  China National Petroleum Corporation                     Oil and gas
#
#   Revenue Profit Employees Headquarters[note 1] State-owned Ref.
# 0     716   79.9   1576000        United States         NaN  [5]
# 1     713   21.8   2100000        United States         NaN  [6]
# 2     545    9.2   1361423                China         NaN  [7]
# 3     480  106.0     73311         Saudi Arabia         NaN  [8]
# 4     476   25.2   1026301                China         NaN  [9]
