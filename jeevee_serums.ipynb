# %%
import requests
import pandas as pd

url = "https://gw.jeevee.com/v1/categories/33/products?page=1&item_per_page=24"
headers = {"User-Agent": "MyProject/1.0 (binii@example.com)"}

r = requests.get(url, headers=headers)
print(r.json())
# Out:
# {'id': 33, 'seo_details': {'title': 'Buy Top Serum For Face - All Skin Types | Get Up to 15% OFF', 'description': 'Shop serums & essence online for all skin types (oily, dry, acne-prone, combination). Formulated with vitamin c, hyaluronic acid, retinol, and vitamin e.', 'slug': 'serums-essence', 'image': {}}, 'description': '<p><br></p>', 'breadcrumb': [{'sequence': 1, 'name': 'SKIN ', 'id': 1, 'seo_details': {'title': 'Best Skincare Products In Nepal Online, Deals & Discounts!!', 'description': 'Shop the best skincare products in Nepal - 100% authentic, top skincare & cosmetics: Moisturizers, sunscreens, & cleansers at huge discounts! only at Jeevee.', 'slug': 'skin', 'image': {}}}, {'sequence': 2, 'name': ' MOISTURIZERS ', 'id': 19, 'seo_details': {'title': 'Moisturizers - For Every Skin [ Oily, Dry, Normal ] Up to 15%', 'description': 'Shop dermatologists pick for the best moisturizers online. Moisturizing cream for oily, dry, acne-prone, sensitive s', 'slug': 'moisturizers', 'image': {}}}, {'sequence': 3, 'name': ' SERUMS & ESSENCE', 'id': 33, 'seo_details': {'title': 'Buy Top Serum For Face - All Skin Types | Get Up to 15% OFF', 'description': 'Shop serums & essence online for all skin types (oily, dry, acne-prone, combination). Formulated with vitamin c, hyaluronic acid, retinol, and vitamin e.', 'slug': 'serums-essence', 'image': {}}}], 'mobile_banner': [], 'has_prev': False, 'name': 'SERUMS & ESSENCE', 'sequence': 58, 'web_banner': [], 'page': 1, 'total_results': 541, 'total_pages': 23, 'has_next': True, 'filters': [{'key': 'price', 'display_name': 'Price', 'type': 'SLIDER', 'min_value': 90, 'max_value': 13000, 'applied_min': 90, 'applied_max': 13000}, {'key': 'brand_ids', 'display_name': 'Brands', 'type': 'CHECKBOX', 'values': [{'id': 306, 'name': 'THE DERMA CO', 'count': 28}, {'id': 1145, 'name': 'PILGRIM', 'count': 24}, {'id': 922, 'name': 'MINIMALIST', 'count': 18}, {'id': 1127, 'name': 'SKIN1004', 'count': 15}, {'id': 853, 'name': 'THE PUREST SOLUTIONS', 'count': 15}, {'id': 3516, 'name': 'JUICY CHEMISTRY', 'count': 14}, {'id': 585, 'name': 'THE ORDINARY', 'count': 14}, {'id': 152, 'name': 'PLUM', 'count': 11}, {'id': 229, 'name': 'ETHICARE', 'count': 11}, {'id': 507, 'name': 'KOIL SKINCARE', 'count': 10}, {'id': 5569, 'name': "LORD'S", 'count': 10}, {'id': 972, 'name': 'INVEDA', 'count': 10}, {'id': 5421, 'name': 'REBONCEL', 'count': 9}, {'id': 570, 'name': 'NEUTRIHERBS', 'count': 9}, {'id': 584, 'name': 'CHEMIST AT PLAY', 'count': 9}, {'id': 688, 'name': 'MELAO', 'count': 9}, {'id': 1045, 'name': 'NATURE DERMA', 'count': 8}, {'id': 251, 'name': 'PAX MOLY', 'count': 8}, {'id': 491, 'name': 'DOT & KEY', 'count': 8}, {'id': 1072, 'name': 'BEAUTY OF JOSEON', 'count': 7}, {'id': 230, 'name': 'RALYCOS', 'count': 7}, {'id': 1052, 'name': 'SINOZ', 'count': 6}, {'id': 1102, 'name': 'HBS', 'count': 6}, {'id': 266, 'name': 'PEACHY TONICS', 'count': 6}, {'id': 2, 'name': 'MAMAEARTH', 'count': 6}, {'id': 3389, 'name': 'MEDICUBE', 'count': 6}, {'id': 509, 'name': 'LAKME', 'count': 6}, {'id': 5364, 'name': 'BIO-ESSENCE', 'count': 6}, {'id': 5482, 'name': 'ORIFLAME', 'count': 6}, {'id': 603, 'name': 'SUGANDA', 'count': 6}, {'id': 605, 'name': "DR. SHETH'S", 'count': 6}, {'id': 648, 'name': 'COSRX', 'count': 6}, {'id': 1112, 'name': 'ANUA', 'count': 5}, {'id': 1114, 'name': 'FOXTALE', 'count': 5}, {'id': 1240, 'name': 'ZUWA COSMETICS', 'count': 5}, {'id': 137, 'name': 'CEUTICOZ', 'count': 5}, {'id': 5147, 'name': "RE'EQUIL", 'count': 5}, {'id': 5448, 'name': 'COSMETEX ROLAND', 'count': 5}, {'id': 5538, 'name': 'EVEN CARE', 'count': 5}, {'id': 5540, 'name': 'HYPHEN', 'count': 5}, {'id': 5574, 'name': 'PROVEN HONEST DERMA', 'count': 5}, {'id': 1120, 'name': 'ELUME', 'count': 4}, {'id': 139, 'name': 'FIXDERMA', 'count': 4}, {'id': 1668, 'name': 'THE AYURVEDA CO', 'count': 4}, {'id': 3390, 'name': 'NUMBUZIN', 'count': 4}, {'id': 3391, 'name': 'PURITO', 'count': 4}, {'id': 360, 'name': 'CASMARA', 'count': 4}, {'id': 3, 'name': 'KLEID ...

# %%
import pandas as pd

data = r.json()
products = data['data']  # the actual product list

records = []
for p in products:
    records.append({
        'name': p['label'],
        'brand': p['brand']['name'],
        'price': p['price'],
        'discount': p['discount'],
        'rating': p['review_and_rating']['avg_rating'],
        'rating_count': p['review_and_rating']['rating_count'],
        'sold_out': p['sold_out'],
    })

df = pd.DataFrame(records)
print(df.head())
# Out:
#                                                 name         brand   price  \
# 0           THE DERMA CO 10% NIACINAMIDE SERUM, 30ML  THE DERMA CO   959.0
# 1           MINIMALIST Vitamin C 10% Face Serum 30ml    MINIMALIST  1121.0
# 2       THE DERMA CO. 10% VITAMIN C FACE SERUM, 30ML  THE DERMA CO  1039.0
# 3           MINIMALIST 16% VITAMIN C FACE SERUM 20ML    MINIMALIST   961.0
# 4  ANUA NIACINAMIDE 10% + TXA 4% DARK SPOT SERUM-...          ANUA  3300.0
#
#    discount  rating  rating_count  sold_out
# 0     9.999     4.6           266     False
# 1     5.001     4.5           121     False
# 2    10.000     4.3           170     False
# 3     5.000     4.6            80     False
# 4    18.788     4.6            18     False

# %%
all_products = []

for page in range(1, 24):  # total_pages = 23
    url = f"https://gw.jeevee.com/v1/categories/33/products?page={page}&item_per_page=24"
    r = requests.get(url, headers=headers)
    data = r.json()

    if 'data' not in data:
        print(f"Skipping page {page} due to API error: {data.get('error', 'Unknown error')}")
        continue

    for p in data['data']:
        all_products.append({
            'name': p['label'],
            'brand': p['brand']['name'],
            'price': p['price'],
            'discount': p.get('discount', 0), # Use .get() to provide a default value if 'discount' key is missing
            'rating': p['review_and_rating']['avg_rating'],
            'rating_count': p['review_and_rating']['rating_count'],
            'sold_out': p['sold_out'],
        })

    print(f"Page {page} done")

df = pd.DataFrame(all_products)
df.to_csv("jeevee_serums.csv", index=False)
print(f"Total: {len(df)} products saved!")
# Out:
# Page 1 done
# Page 2 done
# Page 3 done
# Page 4 done
# Page 5 done
# Page 6 done
# Page 7 done
# Page 8 done
# Page 9 done
# Page 10 done
# Page 11 done
# Page 12 done
# Page 13 done
# Page 14 done
# Page 15 done
# Page 16 done
# Page 17 done
# Page 18 done
# Page 19 done
# Page 20 done
# Page 21 done
# Page 22 done
# Page 23 done
# Total: 541 products saved!

# %%
df.head()
# Out:
#                                                 name         brand   price  \
# 0           THE DERMA CO 10% NIACINAMIDE SERUM, 30ML  THE DERMA CO   959.0
# 1           MINIMALIST Vitamin C 10% Face Serum 30ml    MINIMALIST  1121.0
# 2       THE DERMA CO. 10% VITAMIN C FACE SERUM, 30ML  THE DERMA CO  1039.0
# 3           MINIMALIST 16% VITAMIN C FACE SERUM 20ML    MINIMALIST   961.0
# 4  ANUA NIACINAMIDE 10% + TXA 4% DARK SPOT SERUM-...          ANUA  3300.0
#
#    discount  rating  rating_count  sold_out
# 0     9.999     4.6           266     False
# 1     5.001     4.5           121     False
# 2    10.000     4.3           170     False
# 3     5.000     4.6            80     False
# 4    18.788     4.6            18     False

# %%
from google.colab import files
files.download("jeevee_serums.csv")

# %%
# see all available fields for one product
data = r.json()
print(data['data'][0].keys())
# Out:
# dict_keys(['default_product_id', 'item_id', 'product_id', 'product_template_id', 'label', 'sku_code', 'weight', 'product_category', 'reference_number', 'has_variants', 'default_unit', 'sold_out', 'disabled', 'comment', 'manufacturing_company', 'other_units', 'tags', 'brand', 'narcotic_drug', 'description', 'pharmacy_attribute', 'review_and_rating', 'primary_category', 'variant_information', 'seo_details', 'fire_event', 'image', 'price', 'selling_price_without_vat', 'vat_amount', 'taxes', 'tax', 'is_quickee', 'discount_object', 'discount', 'featured'])
